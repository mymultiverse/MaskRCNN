# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 14555864894086526927, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 4941820723
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 6217866185182417443
#  physical_device_desc: "device: 0, name: GeForce GTX 1060, pci bus id: 0000:01:00.0, compute capability: 6.1"]

# %%
import os
import sys
import json
import datetime
import numpy as np
import skimage.draw

# Root directory of the project
ROOT_DIR = os.path.abspath("../../")

# Import Mask RCNN
sys.path.append(ROOT_DIR)  # To find local version of the library
from mrcnn.config import Config
from mrcnn import model as modellib, utils

# Path to trained weights file
COCO_WEIGHTS_PATH = os.path.join(ROOT_DIR, "mask_rcnn_crater_latest.h5")
weights_path = COCO_WEIGHTS_PATH
# Directory to save logs and model checkpoints, if not provided
# through the command line argument --logs
DEFAULT_LOGS_DIR = os.path.join(ROOT_DIR, "logs")
CRATER_DIR = os.path.join(ROOT_DIR, "datasets/crater")

# %%
class CraterConfig(Config):
    """Configuration for training on the toy  dataset.
    Derives from the base Config class and overrides some values.
    """
    # Give the configuration a recognizable name
    NAME = "crater"

    # We use a GPU with 12GB memory, which can fit two images.
    # Adjust down if you use a smaller GPU.
    IMAGES_PER_GPU = 1

    # Number of classes (including background)
    NUM_CLASSES = 1 + 1  # Background + crater

    # Number of training steps per epoch
    STEPS_PER_EPOCH = 100

    # Skip detections with < 90% confidence
    DETECTION_MIN_CONFIDENCE = 0.9


############################################################
#  Dataset
############################################################

class CraterDataset(utils.Dataset):

    def load_crater(self, dataset_dir, subset):
        """Load a subset of the cratern dataset.
        dataset_dir: Root directory of the dataset.
        subset: Subset to load: train or val
        """
        # Add classes. We have only one class to add.
        self.add_class("crater", 1, "crater")

        # Train or validation dataset?
        assert subset in ["train", "val"]
        dataset_dir = os.path.join(dataset_dir, subset)

        # Load annotations
        # VGG Image Annotator (up to version 1.6) saves each image in the form:
        # { 'filename': '28503151_5b5b7ec140_b.jpg',
        #   'regions': {
        #       '0': {
        #           'region_attributes': {},
        #           'shape_attributes': {
        #               'all_points_x': [...],
        #               'all_points_y': [...],
        #               'name': 'polygon'}},
        #       ... more regions ...
        #   },
        #   'size': 100202
        # }
        # We mostly care about the x and y coordinates of each region
        # Note: In VIA 2.0, regions was changed from a dict to a list.
        annotations = json.load(open(os.path.join(dataset_dir, "via_region_data.json")))
        annotations = list(annotations.values())  # don't need the dict keys

        # The VIA tool saves images in the JSON even if they don't have any
        # annotations. Skip unannotated images.
        annotations = [a for a in annotations if a['regions']]

        # Add images
        for a in annotations:
            # Get the x, y coordinaets of points of the polygons that make up
            # the outline of each object instance. These are stores in the
            # shape_attributes (see json format above)
            # The if condition is needed to support VIA versions 1.x and 2.x.
            if type(a['regions']) is dict:
                polygons = [r['shape_attributes'] for r in a['regions'].values()]
            else:
                polygons = [r['shape_attributes'] for r in a['regions']] 

            # load_mask() needs the image size to convert polygons to masks.
            # Unfortunately, VIA doesn't include it in JSON, so we must read
            # the image. This is only managable since the dataset is tiny.
            image_path = os.path.join(dataset_dir, a['filename'])
            image = skimage.io.imread(image_path)
            height, width = image.shape[:2]

            self.add_image(
                "crater",
                image_id=a['filename'],  # use file name as a unique image id
                path=image_path,
                width=width, height=height,
                polygons=polygons)

    def load_mask(self, image_id):
        """Generate instance masks for an image.
       Returns:
        masks: A bool array of shape [height, width, instance count] with
            one mask per instance.
        class_ids: a 1D array of class IDs of the instance masks.
        """
        # If not a crater dataset image, delegate to parent class.
        image_info = self.image_info[image_id]
        if image_info["source"] != "crater":
            return super(self.__class__, self).load_mask(image_id)

        # Convert polygons to a bitmap mask of shape
        # [height, width, instance_count]
        info = self.image_info[image_id]
        mask = np.zeros([info["height"], info["width"], len(info["polygons"])],
                        dtype=np.uint8)
        for i, p in enumerate(info["polygons"]):
            # Get indexes of pixels inside the polygon and set them to 1
            rr, cc = skimage.draw.polygon(p['all_points_y'], p['all_points_x'])
            mask[rr, cc, i] = 1

        # Return mask, and array of class IDs of each instance. Since we have
        # one class ID only, we return an array of 1s
        return mask.astype(np.bool), np.ones([mask.shape[-1]], dtype=np.int32)

    def image_reference(self, image_id):
        """Return the path of the image."""
        info = self.image_info[image_id]
        if info["source"] == "crater":
            return info["path"]
        else:
            super(self.__class__, self).image_reference(image_id)


def train(model):
    """Train the model."""
    # Training dataset.
    dataset_train = CraterDataset()
    dataset_train.load_crater(CRATER_DIR, "train")
    dataset_train.prepare()

    # Validation dataset
    dataset_val = CraterDataset()
    dataset_val.load_crater(CRATER_DIR, "val")
    dataset_val.prepare()

    # *** This training schedule is an example. Update to your needs ***
    # Since we're using a very small dataset, and starting from
    # COCO trained weights, we don't need to train too long. Also,
    # no need to train all layers, just the heads should do it.
    print("Training network heads")
    model.train(dataset_train, dataset_val,
                learning_rate=config.LEARNING_RATE,
                epochs=30,
                layers='heads')


def color_splash(image, mask):
    """Apply color splash effect.
    image: RGB image [height, width, 3]
    mask: instance segmentation mask [height, width, instance count]

    Returns result image.
    """
    # Make a grayscale copy of the image. The grayscale copy still
    # has 3 RGB channels, though.
    gray = skimage.color.gray2rgb(skimage.color.rgb2gray(image)) * 255
    # Copy color pixels from the original color image where mask is set
    if mask.shape[-1] > 0:
        # We're treating all instances as one, so collapse the mask into one layer
        mask = (np.sum(mask, -1, keepdims=True) >= 1)
        splash = np.where(mask, image, gray).astype(np.uint8)
    else:
        splash = gray.astype(np.uint8)
    return splash


def detect_and_color_splash(model, image_path=None, video_path=None):
    assert image_path or video_path

    # Image or video?
    if image_path:
        # Run model detection and generate the color splash effect
        print("Running on {}".format(args.image))
        # Read image
        image = skimage.io.imread(args.image)
        # Detect objects
        r = model.detect([image], verbose=1)[0]
        # Color splash
        splash = color_splash(image, r['masks'])
        # Save output
        file_name = "splash_{:%Y%m%dT%H%M%S}.png".format(datetime.datetime.now())
        skimage.io.imsave(file_name, splash)
    elif video_path:
        import cv2
        # Video capture
        vcapture = cv2.VideoCapture(video_path)
        width = int(vcapture.get(cv2.CAP_PROP_FRAME_WIDTH))
        height = int(vcapture.get(cv2.CAP_PROP_FRAME_HEIGHT))
        fps = vcapture.get(cv2.CAP_PROP_FPS)

        # Define codec and create video writer
        file_name = "splash_{:%Y%m%dT%H%M%S}.avi".format(datetime.datetime.now())
        vwriter = cv2.VideoWriter(file_name,
                                  cv2.VideoWriter_fourcc(*'MJPG'),
                                  fps, (width, height))

        count = 0
        success = True
        while success:
            print("frame: ", count)
            # Read next image
            success, image = vcapture.read()
            if success:
                # OpenCV returns images as BGR, convert to RGB
                image = image[..., ::-1]
                # Detect objects
                r = model.detect([image], verbose=0)[0]
                # Color splash
                splash = color_splash(image, r['masks'])
                # RGB -> BGR to save image to video
                splash = splash[..., ::-1]
                # Add image to video writer
                vwriter.write(splash)
                count += 1
        vwriter.release()
    print("Saved to ", file_name)

# %%
config = CraterConfig()
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     1
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.9
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 1
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  1024
# IMAGE_META_SIZE                14
# IMAGE_MIN_DIM                  800
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [1024 1024    3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           crater
# NUM_CLASSES                    2
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (32, 64, 128, 256, 512)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                100
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           200
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001

# %%
model = modellib.MaskRCNN(mode="training", config=config, model_dir=DEFAULT_LOGS_DIR)

# %%
model.load_weights(weights_path, by_name=True, exclude=["mrcnn_class_logits", "mrcnn_bbox_fc","mrcnn_bbox", "mrcnn_mask"])
train(model)
# Out:
# Training network heads
#
# Starting at epoch 0. LR=0.001
#
# Checkpoint Path: C:\Users\YOGI\Documents\Mask_RCNN\logs\crater20190326T1429\mask_rcnn_crater_{epoch:04d}.h5
# Selecting layers to train
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# C:\Users\YOGI\Anaconda3\lib\site-packages\tensorflow\python\ops\gradients_impl.py:110: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Epoch 1/30
# 100/100 [==============================] - 280s 3s/step - loss: 0.9602 - rpn_class_loss: 0.0525 - rpn_bbox_loss: 0.1402 - mrcnn_class_loss: 0.2132 - mrcnn_bbox_loss: 0.3156 - mrcnn_mask_loss: 0.2387 - val_loss: 1.6211 - val_rpn_class_loss: 0.1439 - val_rpn_bbox_loss: 0.4953 - val_mrcnn_class_loss: 0.1968 - val_mrcnn_bbox_loss: 0.3529 - val_mrcnn_mask_loss: 0.4322
# Epoch 2/30
# 100/100 [==============================] - 254s 3s/step - loss: 0.6585 - rpn_class_loss: 0.0382 - rpn_bbox_loss: 0.1352 - mrcnn_class_loss: 0.1186 - mrcnn_bbox_loss: 0.1753 - mrcnn_mask_loss: 0.1913 - val_loss: 1.7397 - val_rpn_class_loss: 0.1957 - val_rpn_bbox_loss: 0.5151 - val_mrcnn_class_loss: 0.2198 - val_mrcnn_bbox_loss: 0.3502 - val_mrcnn_mask_loss: 0.4589
# Epoch 3/30
# 100/100 [==============================] - 277s 3s/step - loss: 0.6783 - rpn_class_loss: 0.0454 - rpn_bbox_loss: 0.1325 - mrcnn_class_loss: 0.1403 - mrcnn_bbox_loss: 0.1530 - mrcnn_mask_loss: 0.2071 - val_loss: 1.7207 - val_rpn_class_loss: 0.1578 - val_rpn_bbox_loss: 0.4843 - val_mrcnn_class_loss: 0.2413 - val_mrcnn_bbox_loss: 0.3729 - val_mrcnn_mask_loss: 0.4644
# Epoch 4/30
# 100/100 [==============================] - 269s 3s/step - loss: 0.5776 - rpn_class_loss: 0.0418 - rpn_bbox_loss: 0.1193 - mrcnn_class_loss: 0.1101 - mrcnn_bbox_loss: 0.1227 - mrcnn_mask_loss: 0.1837 - val_loss: 1.6544 - val_rpn_class_loss: 0.1734 - val_rpn_bbox_loss: 0.4590 - val_mrcnn_class_loss: 0.2343 - val_mrcnn_bbox_loss: 0.3449 - val_mrcnn_mask_loss: 0.4426
# Epoch 5/30
# 100/100 [==============================] - 257s 3s/step - loss: 0.5733 - rpn_class_loss: 0.0427 - rpn_bbox_loss: 0.1109 - mrcnn_class_loss: 0.1175 - mrcnn_bbox_loss: 0.1117 - mrcnn_mask_loss: 0.1904 - val_loss: 1.6826 - val_rpn_class_loss: 0.1765 - val_rpn_bbox_loss: 0.4476 - val_mrcnn_class_loss: 0.2189 - val_mrcnn_bbox_loss: 0.3497 - val_mrcnn_mask_loss: 0.4899
# Epoch 6/30
# 100/100 [==============================] - 275s 3s/step - loss: 0.5186 - rpn_class_loss: 0.0364 - rpn_bbox_loss: 0.0958 - mrcnn_class_loss: 0.1026 - mrcnn_bbox_loss: 0.1004 - mrcnn_mask_loss: 0.1834 - val_loss: 1.6669 - val_rpn_class_loss: 0.1644 - val_rpn_bbox_loss: 0.4415 - val_mrcnn_class_loss: 0.2335 - val_mrcnn_bbox_loss: 0.3526 - val_mrcnn_mask_loss: 0.4748
# Epoch 7/30
# 100/100 [==============================] - 276s 3s/step - loss: 0.5595 - rpn_class_loss: 0.0461 - rpn_bbox_loss: 0.1152 - mrcnn_class_loss: 0.1062 - mrcnn_bbox_loss: 0.1050 - mrcnn_mask_loss: 0.1870 - val_loss: 1.8997 - val_rpn_class_loss: 0.2192 - val_rpn_bbox_loss: 0.5323 - val_mrcnn_class_loss: 0.3000 - val_mrcnn_bbox_loss: 0.3546 - val_mrcnn_mask_loss: 0.4936
# Epoch 8/30
# 100/100 [==============================] - 263s 3s/step - loss: 0.5357 - rpn_class_loss: 0.0403 - rpn_bbox_loss: 0.1052 - mrcnn_class_loss: 0.1012 - mrcnn_bbox_loss: 0.1009 - mrcnn_mask_loss: 0.1882 - val_loss: 1.8073 - val_rpn_class_loss: 0.1845 - val_rpn_bbox_loss: 0.4476 - val_mrcnn_class_loss: 0.3032 - val_mrcnn_bbox_loss: 0.3559 - val_mrcnn_mask_loss: 0.5161
# Epoch 9/30
# 100/100 [==============================] - 281s 3s/step - loss: 0.5141 - rpn_class_loss: 0.0395 - rpn_bbox_loss: 0.0995 - mrcnn_class_loss: 0.1039 - mrcnn_bbox_loss: 0.0904 - mrcnn_mask_loss: 0.1808 - val_loss: 1.7658 - val_rpn_class_loss: 0.1887 - val_rpn_bbox_loss: 0.4657 - val_mrcnn_class_loss: 0.3022 - val_mrcnn_bbox_loss: 0.3329 - val_mrcnn_mask_loss: 0.4764
# Epoch 10/30
# 100/100 [==============================] - 273s 3s/step - loss: 0.5212 - rpn_class_loss: 0.0461 - rpn_bbox_loss: 0.0994 - mrcnn_class_loss: 0.1067 - mrcnn_bbox_loss: 0.0908 - mrcnn_mask_loss: 0.1782 - val_loss: 1.7926 - val_rpn_class_loss: 0.2008 - val_rpn_bbox_loss: 0.4791 - val_mrcnn_class_loss: 0.2593 - val_mrcnn_bbox_loss: 0.3536 - val_mrcnn_mask_loss: 0.4999
# Epoch 11/30
# 100/100 [==============================] - 268s 3s/step - loss: 0.5046 - rpn_class_loss: 0.0417 - rpn_bbox_loss: 0.1000 - mrcnn_class_loss: 0.0998 - mrcnn_bbox_loss: 0.0831 - mrcnn_mask_loss: 0.1800 - val_loss: 1.6813 - val_rpn_class_loss: 0.1727 - val_rpn_bbox_loss: 0.4745 - val_mrcnn_class_loss: 0.2152 - val_mrcnn_bbox_loss: 0.3535 - val_mrcnn_mask_loss: 0.4654
# Epoch 12/30
# 100/100 [==============================] - 443s 4s/step - loss: 0.4396 - rpn_class_loss: 0.0312 - rpn_bbox_loss: 0.0895 - mrcnn_class_loss: 0.0833 - mrcnn_bbox_loss: 0.0732 - mrcnn_mask_loss: 0.1623 - val_loss: 1.7806 - val_rpn_class_loss: 0.1986 - val_rpn_bbox_loss: 0.4485 - val_mrcnn_class_loss: 0.2792 - val_mrcnn_bbox_loss: 0.3397 - val_mrcnn_mask_loss: 0.5147
# Epoch 13/30
# 100/100 [==============================] - 512s 5s/step - loss: 0.4960 - rpn_class_loss: 0.0369 - rpn_bbox_loss: 0.1058 - mrcnn_class_loss: 0.0984 - mrcnn_bbox_loss: 0.0796 - mrcnn_mask_loss: 0.1752 - val_loss: 1.7606 - val_rpn_class_loss: 0.1804 - val_rpn_bbox_loss: 0.4608 - val_mrcnn_class_loss: 0.2489 - val_mrcnn_bbox_loss: 0.3537 - val_mrcnn_mask_loss: 0.5168
# Epoch 14/30
# 100/100 [==============================] - 519s 5s/step - loss: 0.4614 - rpn_class_loss: 0.0355 - rpn_bbox_loss: 0.0911 - mrcnn_class_loss: 0.0893 - mrcnn_bbox_loss: 0.0763 - mrcnn_mask_loss: 0.1692 - val_loss: 1.9125 - val_rpn_class_loss: 0.2099 - val_rpn_bbox_loss: 0.4789 - val_mrcnn_class_loss: 0.3142 - val_mrcnn_bbox_loss: 0.3539 - val_mrcnn_mask_loss: 0.5555
# Epoch 15/30
# 100/100 [==============================] - 514s 5s/step - loss: 0.5193 - rpn_class_loss: 0.0383 - rpn_bbox_loss: 0.1112 - mrcnn_class_loss: 0.0918 - mrcnn_bbox_loss: 0.0909 - mrcnn_mask_loss: 0.1871 - val_loss: 1.8210 - val_rpn_class_loss: 0.2003 - val_rpn_bbox_loss: 0.4826 - val_mrcnn_class_loss: 0.2984 - val_mrcnn_bbox_loss: 0.3528 - val_mrcnn_mask_loss: 0.4870
# Epoch 16/30
# 100/100 [==============================] - 510s 5s/step - loss: 0.4454 - rpn_class_loss: 0.0331 - rpn_bbox_loss: 0.0871 - mrcnn_class_loss: 0.0791 - mrcnn_bbox_loss: 0.0746 - mrcnn_mask_loss: 0.1715 - val_loss: 1.8459 - val_rpn_class_loss: 0.1972 - val_rpn_bbox_loss: 0.4630 - val_mrcnn_class_loss: 0.2793 - val_mrcnn_bbox_loss: 0.3535 - val_mrcnn_mask_loss: 0.5529
# Epoch 17/30
# 100/100 [==============================] - 504s 5s/step - loss: 0.4675 - rpn_class_loss: 0.0356 - rpn_bbox_loss: 0.1049 - mrcnn_class_loss: 0.0861 - mrcnn_bbox_loss: 0.0711 - mrcnn_mask_loss: 0.1699 - val_loss: 1.9382 - val_rpn_class_loss: 0.2298 - val_rpn_bbox_loss: 0.4965 - val_mrcnn_class_loss: 0.3262 - val_mrcnn_bbox_loss: 0.3523 - val_mrcnn_mask_loss: 0.5334
# Epoch 18/30
# 100/100 [==============================] - 411s 4s/step - loss: 0.4150 - rpn_class_loss: 0.0342 - rpn_bbox_loss: 0.0840 - mrcnn_class_loss: 0.0710 - mrcnn_bbox_loss: 0.0652 - mrcnn_mask_loss: 0.1605 - val_loss: 1.7422 - val_rpn_class_loss: 0.1695 - val_rpn_bbox_loss: 0.4335 - val_mrcnn_class_loss: 0.3052 - val_mrcnn_bbox_loss: 0.3349 - val_mrcnn_mask_loss: 0.4991
# Epoch 19/30
# 100/100 [==============================] - 274s 3s/step - loss: 0.4570 - rpn_class_loss: 0.0361 - rpn_bbox_loss: 0.0973 - mrcnn_class_loss: 0.0846 - mrcnn_bbox_loss: 0.0702 - mrcnn_mask_loss: 0.1688 - val_loss: 1.8370 - val_rpn_class_loss: 0.1688 - val_rpn_bbox_loss: 0.4794 - val_mrcnn_class_loss: 0.2830 - val_mrcnn_bbox_loss: 0.3365 - val_mrcnn_mask_loss: 0.5693
# Epoch 20/30
# 100/100 [==============================] - 262s 3s/step - loss: 0.4224 - rpn_class_loss: 0.0300 - rpn_bbox_loss: 0.0903 - mrcnn_class_loss: 0.0762 - mrcnn_bbox_loss: 0.0677 - mrcnn_mask_loss: 0.1582 - val_loss: 1.7817 - val_rpn_class_loss: 0.2114 - val_rpn_bbox_loss: 0.4425 - val_mrcnn_class_loss: 0.2953 - val_mrcnn_bbox_loss: 0.3192 - val_mrcnn_mask_loss: 0.5132
# Epoch 21/30
# 100/100 [==============================] - 273s 3s/step - loss: 0.4456 - rpn_class_loss: 0.0324 - rpn_bbox_loss: 0.1005 - mrcnn_class_loss: 0.0750 - mrcnn_bbox_loss: 0.0671 - mrcnn_mask_loss: 0.1706 - val_loss: 2.0468 - val_rpn_class_loss: 0.2728 - val_rpn_bbox_loss: 0.5091 - val_mrcnn_class_loss: 0.3360 - val_mrcnn_bbox_loss: 0.3653 - val_mrcnn_mask_loss: 0.5635
# Epoch 22/30
# 100/100 [==============================] - 268s 3s/step - loss: 0.4084 - rpn_class_loss: 0.0310 - rpn_bbox_loss: 0.0821 - mrcnn_class_loss: 0.0705 - mrcnn_bbox_loss: 0.0622 - mrcnn_mask_loss: 0.1626 - val_loss: 1.7532 - val_rpn_class_loss: 0.1877 - val_rpn_bbox_loss: 0.4700 - val_mrcnn_class_loss: 0.2974 - val_mrcnn_bbox_loss: 0.3188 - val_mrcnn_mask_loss: 0.4792
# Epoch 23/30
# 100/100 [==============================] - 265s 3s/step - loss: 0.3809 - rpn_class_loss: 0.0284 - rpn_bbox_loss: 0.0747 - mrcnn_class_loss: 0.0649 - mrcnn_bbox_loss: 0.0591 - mrcnn_mask_loss: 0.1539 - val_loss: 2.0331 - val_rpn_class_loss: 0.2517 - val_rpn_bbox_loss: 0.5323 - val_mrcnn_class_loss: 0.3174 - val_mrcnn_bbox_loss: 0.3663 - val_mrcnn_mask_loss: 0.5654
# Epoch 24/30
# 100/100 [==============================] - 270s 3s/step - loss: 0.4085 - rpn_class_loss: 0.0311 - rpn_bbox_loss: 0.0844 - mrcnn_class_loss: 0.0744 - mrcnn_bbox_loss: 0.0614 - mrcnn_mask_loss: 0.1572 - val_loss: 1.9484 - val_rpn_class_loss: 0.2384 - val_rpn_bbox_loss: 0.4573 - val_mrcnn_class_loss: 0.3691 - val_mrcnn_bbox_loss: 0.3453 - val_mrcnn_mask_loss: 0.5383
# Epoch 25/30
# 100/100 [==============================] - 270s 3s/step - loss: 0.4072 - rpn_class_loss: 0.0302 - rpn_bbox_loss: 0.0884 - mrcnn_class_loss: 0.0710 - mrcnn_bbox_loss: 0.0594 - mrcnn_mask_loss: 0.1582 - val_loss: 2.0009 - val_rpn_class_loss: 0.2721 - val_rpn_bbox_loss: 0.4635 - val_mrcnn_class_loss: 0.3805 - val_mrcnn_bbox_loss: 0.3400 - val_mrcnn_mask_loss: 0.5448
# Epoch 26/30
# 100/100 [==============================] - 262s 3s/step - loss: 0.3729 - rpn_class_loss: 0.0242 - rpn_bbox_loss: 0.0677 - mrcnn_class_loss: 0.0672 - mrcnn_bbox_loss: 0.0567 - mrcnn_mask_loss: 0.1572 - val_loss: 2.0452 - val_rpn_class_loss: 0.2493 - val_rpn_bbox_loss: 0.5243 - val_mrcnn_class_loss: 0.3741 - val_mrcnn_bbox_loss: 0.3605 - val_mrcnn_mask_loss: 0.5370
# Epoch 27/30
# 100/100 [==============================] - 268s 3s/step - loss: 0.3754 - rpn_class_loss: 0.0307 - rpn_bbox_loss: 0.0753 - mrcnn_class_loss: 0.0689 - mrcnn_bbox_loss: 0.0543 - mrcnn_mask_loss: 0.1462 - val_loss: 2.0496 - val_rpn_class_loss: 0.2303 - val_rpn_bbox_loss: 0.4548 - val_mrcnn_class_loss: 0.4545 - val_mrcnn_bbox_loss: 0.3376 - val_mrcnn_mask_loss: 0.5724
# Epoch 28/30
# 100/100 [==============================] - 256s 3s/step - loss: 0.3764 - rpn_class_loss: 0.0254 - rpn_bbox_loss: 0.0930 - mrcnn_class_loss: 0.0628 - mrcnn_bbox_loss: 0.0510 - mrcnn_mask_loss: 0.1442 - val_loss: 2.2397 - val_rpn_class_loss: 0.3649 - val_rpn_bbox_loss: 0.5510 - val_mrcnn_class_loss: 0.3740 - val_mrcnn_bbox_loss: 0.3548 - val_mrcnn_mask_loss: 0.5950
# Epoch 29/30
# 100/100 [==============================] - 275s 3s/step - loss: 0.4129 - rpn_class_loss: 0.0303 - rpn_bbox_loss: 0.0874 - mrcnn_class_loss: 0.0770 - mrcnn_bbox_loss: 0.0581 - mrcnn_mask_loss: 0.1602 - val_loss: 1.8289 - val_rpn_class_loss: 0.1974 - val_rpn_bbox_loss: 0.4469 - val_mrcnn_class_loss: 0.2917 - val_mrcnn_bbox_loss: 0.3303 - val_mrcnn_mask_loss: 0.5625
# Epoch 30/30
# 100/100 [==============================] - 261s 3s/step - loss: 0.3829 - rpn_class_loss: 0.0251 - rpn_bbox_loss: 0.0861 - mrcnn_class_loss: 0.0581 - mrcnn_bbox_loss: 0.0597 - mrcnn_mask_loss: 0.1539 - val_loss: 2.1228 - val_rpn_class_loss: 0.3130 - val_rpn_bbox_loss: 0.5174 - val_mrcnn_class_loss: 0.3906 - val_mrcnn_bbox_loss: 0.3508 - val_mrcnn_mask_loss: 0.5510
